# %%
#Specific growth rates of algae (divisions per day) at different light intensities and temperatures
'''
Notes.
Marine species at 35ppt salinity, 
Freshwater species at 0 ppt.salinity, 
24 hour light for all species
'''

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Algae.csv')
tu1 = ('Temperature', 5, 5, 10, 10, 25, 25, 30, 30)
tu2 = ('Intensity (lux)', 5000, 2500, 5000, 2500, 5000, 2500, 5000, 2500)
df.columns = ['Temperature', 5, 5, 10, 10, 25, 25, 30, 30]
#df.columns = pd.MultiIndex.from_tuples([tu1, tu2])
df
# Out:
#                              Temperature        5        5     10       10  \
# 0             Light      Intensity (lux)  5000.00  2500.00   5000  2500.00
# 1                                Species      NaN      NaN    NaN      NaN
# 2                     Caloneis schroderi    -0.01    -0.50   -0.1     0.25
# 3                   Chaetoceros gracilis    -0.01    -0.05   0.16     0.07
# 4                    Chaetoceros simplex    -0.06    -0.01   0.27     0.55
# 5                  Chlorella ellipsoidea     0.03     0.02   0.58     0.53
# 6                Chlorella stigmatophora     0.01     0.24   0.36     0.24
# 7   Chlorella vulgaris      (freshwater)    -0.25     0.00   0.21     0.17
# 8                 Dunaniella tertiolecta     0.28     0.17   0.43     0.42
# 9                  Cyclotella sp. NUFP-9     0.16     0.08      0    -0.10
# 10                       Hanzchia marina    -0.36    -0.07  -0.68    -0.21
# ...
